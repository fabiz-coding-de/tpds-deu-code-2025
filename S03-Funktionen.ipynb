# %% [markdown]
# ## Seminaraufgabe 3. Benutzerdefinierte Funktionen

# %% [markdown]
# ## Lernen: benutzerdefinierte Funktionen
#
# Lese die Abschnitte 4.7-4.11 aus dem Buch **["Python für alle"](http://do1.dr-chuck.com/pythonlearn/DE_de/pythonlearn.pdf)** von C. Severance.<br>Verwende Code-Zellen um die folgenden Beispiele auszuführen.

# %% [markdown]
# **Beispiele im Abschnitt 4.7, 4.8**

# %%
# Code ausfüllen (Seite 58), dann ausführen
def print_lyrics():
    <...> # Code hier schreiben

# %%
print(print_lyrics)

# %%
print(type(print_lyrics))

# %%
# Die Funktion print_lyrics() aufrufen:
<...> # Code hier schreiben

# %%
# Die Funktion repeat_lyrics() definieren:
<...>

# %%
# ... dann aufrufen:
<...>

# %%
# Gesamtes "Programm":
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print('I sleep all night and I work all day.')
    
def repeat_lyrics():
    print_lyrics()
    print_lyrics()

repeat_lyrics()

# %% [markdown]
# **Übung A:** Versetzen Sie die letzte Zeile dieses Programms an den Anfang, sodass
# der Funktionsaufruf vor den Definitionen erscheint. Führen Sie das Programm aus
# und beobachten Sie, welche Fehlermeldung Sie erhalten.
#
# *Hinweise: Eine neue Zelle für die Lösung erstellen. Vor dem Ausfuhren, das Kernel neustarten.*

# %% [markdown]
# **Übung B:** Verschieben Sie den Funktionsaufruf wieder nach unten und verschieben
# Sie die Definition von print_lyrics hinter die Definition von repeat_lyrics. Was
# passiert, wenn Sie dieses Programm ausführen? (Neue Zelle für Lösung erstellen).
#
# *Hinweise: Eine neue Zelle für die Lösung erstellen. Vor dem Ausfuhren, das Kernel neustarten.*

# %% [markdown]
# **Beispiele im Abschnitt 4.10**

# %%
# Eine Funktion mit Argument definieren (S. 61)
<...> # Code hier schreiben

# %%
# Ausführung der Funktion mit den Parametern: Spam, 17, math.pi
<...>

# %%
# Ausführung der Funktion mit den Parametern: 'Spam '*4, math.cos(math.pi), michael
<...>

# %% [markdown]
# **Beispiele im Abschnitt 4.11**

# %%
# Zeige den Rückgabewert der Funktion print_twice() - S. 62-63
result = <...>
<...>

# %%
# Datentyp von None anzeigen:
type( <...> )

# %%
# Die Funktion addtwo definieren und testen
<...>

# %% [markdown]
# ## Übung 1: BMI-Funktion
#
# Eine Funktion für die BMI Berechnung definieren und mit über die Tastatur eingegebene Argumente, aufrufen.
#
# Die BMI-Kennzahl wird berechnet nach der Formel:
#
# $$
# BMI=\frac{Körpergewicht}{Körpergröße^2}
# $$

# %%
# Die Funktion hier definieren
...

# %%
# Werte Eingeben, die Funktion aufrufen
...

# %% [markdown]
# ## Übung 2: Die Fakultät einer Zahl
# Eine Funktion für die Berechnung von n! (N Fakultät) definieren.
# Die Funktion soll, als Parameter, eine positive Ganzzahl n haben.
#
# $$
# n!=1\cdot2\cdot3\cdot ... \cdot n
# $$
#
# Dann, die Funktion für alle Werte n, von 1 bis 20, aufrufen, und die Ergebnisse in eine Liste speichern.

# %%
# Die Funktion hier definieren
...

# %%
# Funktion für n von 1 bis 20 aufrufen, in Liste speichern
...

# Die Liste ausgeben

# %% [markdown]
# ## Übung C3: N Fakultät, rekursiv
#
# Eine rekursive Funktion für dieselbe Aufgabe (s. Übung 2) codieren und testen.
